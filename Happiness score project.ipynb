# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# In this dataset we have 158 rows and 12 cols. and here no null values are present

# %%
# checking the value counts

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Country
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: count, Length: 158, dtype: int64
#
#
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64
#
#
# Happiness Rank
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: count, Length: 157, dtype: int64
#
#
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# No null values are present

# %%
# separating categorical cols and numerical cols

# %%
cat_col=[]
num_col=[]
for i in df.columns:
    if df.dtypes[i] == 'object':
        cat_col.append(i)
    else:
        num_col.append(i)

print('categorical columns are :',cat_col)
print('\n')
print('numerical columns are :',num_col)
# Out:
# categorical columns are : ['Country', 'Region']
#
#
# numerical columns are : ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
# Plotting the LM plot

# %%
sns.lmplot(x='Happiness Score',y='Standard Error',data=df)

# %% [markdown]
# Somehow standard error and Happiness score has slightly negative correlation

# %%
sns.lmplot(x='Happiness Score',y='Economy (GDP per Capita)',data=df)

# %% [markdown]
# Happiness score and Economy is strong positive correlated

# %%
sns.lmplot(x='Happiness Score',y='Health (Life Expectancy)',data=df)

# %% [markdown]
# Happiness score and health are also positive correlated

# %%
sns.lmplot(x='Happiness Score',y='Family',data=df)

# %% [markdown]
# Happiness score and family col has positive correlation

# %%
sns.lmplot(x='Happiness Score',y='Freedom',data=df)

# %% [markdown]
# Happiness score and freedom has positive correlation

# %%
sns.lmplot(x='Happiness Score',y='Trust (Government Corruption)',data=df)

# %% [markdown]
# Happiness score and trust has slightly positive correlation

# %%
sns.lmplot(x='Happiness Score',y='Generosity',data=df)

# %%
sns.lmplot(x='Happiness Score',y='Dystopia Residual',data=df)

# %% [markdown]
# Both has positive correlation

# %%
# Creating Regplot for better understanding the relationship between the cols

# %%
plt.figure(figsize=(15,15),facecolor='white')
plotnum=1
for i in num_col:
    if plotnum<=10:
        ax=plt.subplot(4,3,plotnum)
        sns.regplot(x=i,y='Happiness Score',data=df,color='red')
        plt.xlabel(i)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# Now we can see the relationship b/w the cols

# %%
#Creating Distplot

# %%
plt.figure(figsize=(15,15),facecolor='white')
plotnum=1
for i in num_col:
    if plotnum<=10:
        ax=plt.subplot(4,3,plotnum)
        sns.distplot(df[i],color='m')
        plt.xlabel(i)
    plotnum+=1
plt.tight_layout()

# %%
df[num_col].skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# 'Standard Error','Trust (Government Corruption)','Generosity'  these cols has skewness that need to be removed

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
a=['Standard Error','Trust (Government Corruption)','Generosity']

# %%
# removing skewness by using cuberoot method

# %%
for i in a:
    df[i]=np.cbrt(df[i])

# %%
df[num_col].skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.011932
# Generosity                      -0.961079
# Dystopia Residual               -0.238911
# dtype: float64

# %%
plt.figure(figsize=(15,15),facecolor='white')
plotnum=1
for i in num_col:
    if plotnum<=10:
        ax=plt.subplot(4,3,plotnum)
        sns.distplot(df[i],color='m')
        plt.xlabel(i)
    plotnum+=1
plt.tight_layout()

# %%
# Lets check the outliers by plotting the boxplot
plt.figure(figsize=(10,6),facecolor='white')
plotnumber =1
for col in num_col:
    if plotnumber <= 10:
        ax = plt.subplot(3,4,plotnumber)
        sns.boxplot(df[col],color = 'm')
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation =0,fontsize=12)
    plotnumber += 1
plt.tight_layout()

# %%
sns.boxplot(df['Standard Error'],color='m')
# Out:
# <Axes: >

# %%
from scipy.stats import zscore

# %%
# Encoding categorical col to numerical col by using Ordinal Encoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OE=OrdinalEncoder()

# %%
for i in df.columns:
    if df.dtypes[i]=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587        0.324310
# 1       58.0     9.0               2            7.561        0.365532
# 2       37.0     9.0               3            7.527        0.321658
# 3      105.0     9.0               4            7.522        0.338540
# 4       24.0     5.0               5            7.427        0.328749
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465        0.325981
# 154     13.0     8.0             155            3.340        0.331896
# 155    136.0     4.0             156            3.006        0.368771
# 156     21.0     8.0             157            2.905        0.442391
# 157    141.0     8.0             158            2.839        0.406700
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# Now all the columns are converted into numerical cols

# %%
# Checking the correlation between the cols

# %%
cor=df.corr()
cor
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.025445 -0.047720        0.182211
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.059858  0.213506       -0.304207
# Generosity                     0.115876  0.269423       -0.141914
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
# visualization of correlation by heatmap 
plt.figure(figsize=(20,15))
sns.heatmap(cor,linewidths = .1,fmt='.1g',linecolor = 'black',annot = True,cmap = 'Blues_r')
plt.yticks(rotation =0)
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
cor['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.326229
# Generosity                       0.159029
# Country                          0.083380
# Region                          -0.176791
# Standard Error                  -0.201754
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %%
# Here we can see that Country col has very less correlation with the Happiness score col

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
x=df.drop('Happiness Score',axis=1)

# %%
y=df['Happiness Score']

# %%
# Checking the variance_inflation_factor

# %%
ds=pd.DataFrame()
ds['col']=x.columns
ds['vif']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
ds
# Out:
#                               col        vif
# 0                         Country   4.157572
# 1                          Region   5.562451
# 2                  Happiness Rank  14.491451
# 3                  Standard Error  94.639347
# 4        Economy (GDP per Capita)  26.339415
# 5                          Family  28.780590
# 6        Health (Life Expectancy)  25.502088
# 7                         Freedom  18.071726
# 8   Trust (Government Corruption)  16.050207
# 9                      Generosity  32.971145
# 10              Dystopia Residual  22.036919

# %%
# Dropping Happiness Rank col because it has of no use

# %%
x.drop('Happiness Rank',axis=1,inplace=True)

# %%
x
# Out:
#      Country  Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0      135.0     9.0        0.324310                   1.39651  1.34951
# 1       58.0     9.0        0.365532                   1.30232  1.40223
# 2       37.0     9.0        0.321658                   1.32548  1.36058
# 3      105.0     9.0        0.338540                   1.45900  1.33095
# 4       24.0     5.0        0.328749                   1.32629  1.32261
# ..       ...     ...             ...                       ...      ...
# 153    118.0     8.0        0.325981                   0.22208  0.77370
# 154     13.0     8.0        0.331896                   0.28665  0.35386
# 155    136.0     4.0        0.368771                   0.66320  0.47489
# 156     21.0     8.0        0.442391                   0.01530  0.41587
# 157    141.0     8.0        0.406700                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
# Using standard scaler

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
x = pd.DataFrame(st.fit_transform(x), columns = x.columns)
x
# Out:
#       Country    Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0    1.238770  1.300256       -0.892612                  1.369621  1.320281
# 1   -0.449465  1.300256        0.172283                  1.135226  1.514458
# 2   -0.909893  1.300256       -0.961125                  1.192861  1.361054
# 3    0.581016  1.300256       -0.524996                  1.525130  1.251922
# 4   -1.194920 -0.040302       -0.777930                  1.194876  1.221204
# ..        ...       ...             ...                       ...       ...
# 153  0.866043  0.965117       -0.849442                 -1.552987 -0.800520
# 154 -1.436096  0.965117       -0.696643                 -1.392303 -2.346860
# 155  1.260695 -0.375441        0.255966                 -0.455245 -1.901086
# 156 -1.260695  0.965117        2.157804                 -2.067566 -2.118467
# 157  1.370321  0.965117        1.235787                 -1.586334 -3.134725
#
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
# Checking for the best random_state value

# %%
maxacc=0
maxrs=0
for i in range(200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    RFR=RandomForestRegressor()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxacc:
        maxacc=acc
        maxrs=i

print('max accuracy is :',maxacc,'random state :',maxrs)
# Out:
# max accuracy is : 0.9572598332157782 random state : 106

# %%
# splitting our dataset based on the best random_state value

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=maxrs)

# %%
# Importing regression algorithms

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
# making their instances

# %%
LR=LinearRegression()
RD=Ridge()
LS=Lasso()
EN=ElasticNet()
svr=SVR()
DTR = DecisionTreeRegressor()
GB=GradientBoostingRegressor()
RFR=RandomForestRegressor()

# %%
# Creating a loop with the instances

# %%
loop=[LR,RD,LS,EN,svr,DTR,GB,RFR]

# %%
from sklearn.model_selection import cross_val_score

# %%
# In this loop I am training my model for each algorithmn to check the r2_score,mean_abs_error,mean_squared_error,root mean squared error, cross_val_score and the difference between mean cross_val_score and r2_score

# %%
for i in loop:
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    print('This is for :',i)
    print('r2_score will be :',r2_score(y_test,pred))
    print('mean abs error will be :',mean_absolute_error(y_test,pred))
    print('mean squared error will be :',mean_squared_error(y_test,pred))
    print('root mean squared error will be :',np.sqrt(mean_squared_error(y_test,pred)))
    print('\n')
    score=cross_val_score(i,x,y,cv=5)
    print(score)
    print('mean CV :',score.mean())
    print("difference between mean CV and r2_score will be :",r2_score(y_test,pred)-score.mean())
    print('\n')
# Out:
# This is for : LinearRegression()
# r2_score will be : 0.9939523008329622
# mean abs error will be : 0.05131375890878215
# mean squared error will be : 0.0073591613883256905
# root mean squared error will be : 0.08578555466001074
#
#
# [0.92068065 0.89533812 0.87374459 0.65228667 0.9726167 ]
# mean CV : 0.8629333461153976
# difference between mean CV and r2_score will be : 0.13101895471756453
#
#
# This is for : Ridge()
# r2_score will be : 0.9939332909196487
# mean abs error will be : 0.05233969099266858
# mean squared error will be : 0.007382293659986064
# root mean squared error will be : 0.0859202750227562
#
#
# [0.88927379 0.8965257  0.87166907 0.65947129 0.97255549]
# mean CV : 0.8578990696073496
# difference between mean CV and r2_score will be : 0.13603422131229903
#
#
# This is for : Lasso()
# r2_score will be : -0.0031244384076560827
# mean abs error will be : 0.94265625
# mean squared error will be : 1.2206550674760641
# root mean squared error will be : 1.1048325970372452
# ...

# %%
# Here Linear Regression model has the best performance and less overfitting

# %%
# Lets do the hyper parameter tuning by using grid search cv

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'fit_intercept': [True, 'bool'], 'n_jobs': ['int', None],'copy_X':['bool',True]}

# %%
GCV=GridSearchCV(LinearRegression(),parameters,cv=5,n_jobs=-1)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'copy_X': ['bool', True],
#                          'fit_intercept': [True, 'bool'],
#                          'n_jobs': ['int', None]})

# %%
GCV.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None}

# %%
final_model=LinearRegression(copy_X=True,fit_intercept=True,n_jobs=None)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc= r2_score(y_test,pred)
print(acc*100)
# Out:
# 99.39523008329621

# %%
# so our final model has the accoracy of 99.39%

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587        0.324310
# 1       58.0     9.0               2            7.561        0.365532
# 2       37.0     9.0               3            7.527        0.321658
# 3      105.0     9.0               4            7.522        0.338540
# 4       24.0     5.0               5            7.427        0.328749
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465        0.325981
# 154     13.0     8.0             155            3.340        0.331896
# 155    136.0     4.0             156            3.006        0.368771
# 156     21.0     8.0             157            2.905        0.442391
# 157    141.0     8.0             158            2.839        0.406700
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
# Lets test our model

# %%
t=np.array([1.238770,	1.300256,	-0.892612,	1.369621,	1.320281,	1.263408,	1.577438,	1.826993,	0.576890,	0.758258]).reshape(1,-1)
final_model.predict(t)
# Out:
# array([7.56095834])

# %%
#7.587

# %%
t=np.array([0.866043,	0.965117,	-0.849442,	-1.552987,	-0.800520,	-0.818610,	1.087740,	2.318782,	0.104570,	-2.588925]).reshape(1,-1)
final_model.predict(t)
# Out:
# array([3.35749079])

# %%
#3.465
